# %%
import anndata
import scvelo as scv
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
sample_792 = pd.read_csv("../results/RNA velocity/cells/792.csv")
umap_792 = pd.read_csv("../results/RNA velocity/embeddings/792.csv")
clusters_792 = pd.read_csv("../results/RNA velocity/clusters/792.csv")
sample_792_loom = anndata.read_loom("../results/kb_count/792/counts_unfiltered/adata.loom")

# %%
sample_780 = pd.read_csv("../results/RNA velocity/cells/780.csv")
umap_780 = pd.read_csv("../results/RNA velocity/embeddings/780.csv")
clusters_780 = pd.read_csv("../results/RNA velocity/clusters/780.csv")
sample_780_loom = anndata.read_loom("../results/kb_count/780/counts_unfiltered/adata.loom")

# %%
sample_794 = pd.read_csv("../results/RNA velocity/cells/794.csv")
umap_794 = pd.read_csv("../results/RNA velocity/embeddings/794.csv")
clusters_794 = pd.read_csv("../results/RNA velocity/clusters/794.csv")
sample_794_loom = anndata.read_loom("../results/kb_count/794/counts_unfiltered/adata.loom")

# %%
sample_779 = pd.read_csv("../results/RNA velocity/cells/779.csv")
umap_779 = pd.read_csv("../results/RNA velocity/embeddings/779.csv")
clusters_779 = pd.read_csv("../results/RNA velocity/clusters/779.csv")
sample_779_loom = anndata.read_loom("../results/kb_count/779/counts_unfiltered/adata.loom")

# %%
sample_778 = pd.read_csv("../results/RNA velocity/cells/778.csv")
umap_778 = pd.read_csv("../results/RNA velocity/embeddings/778.csv")
clusters_778 = pd.read_csv("../results/RNA velocity/clusters/778.csv")
sample_778_loom = anndata.read_loom("../results/kb_count/778/counts_unfiltered/adata.loom")

# %%
sample_793 = pd.read_csv("../results/RNA velocity/cells/793.csv")
umap_793 = pd.read_csv("../results/RNA velocity/embeddings/793.csv")
clusters_793 = pd.read_csv("../results/RNA velocity/clusters/793.csv")
sample_793_loom = anndata.read_loom("../results/kb_count/793/counts_unfiltered/adata.loom")

# %%
sample_791 = pd.read_csv("../results/RNA velocity/cells/791.csv")
umap_791 = pd.read_csv("../results/RNA velocity/embeddings/791.csv")
clusters_791 = pd.read_csv("../results/RNA velocity/clusters/791.csv")
sample_791_loom = anndata.read_loom("../results/kb_count/791/counts_unfiltered/adata.loom")

# %%
sample_789 = pd.read_csv("../results/RNA velocity/cells/789.csv")
umap_789 = pd.read_csv("../results/RNA velocity/embeddings/789.csv")
clusters_789 = pd.read_csv("../results/RNA velocity/clusters/789.csv")
sample_789_loom = anndata.read_loom("../results/kb_count/789/counts_unfiltered/adata.loom")

# %%
sample_786 = pd.read_csv("../results/RNA velocity/cells/786.csv")
umap_786 = pd.read_csv("../results/RNA velocity/embeddings/786.csv")
clusters_786 = pd.read_csv("../results/RNA velocity/clusters/786.csv")
sample_786_loom = anndata.read_loom("../results/kb_count/786/counts_unfiltered/adata.loom")

# %%
sample_800 = pd.read_csv("../results/RNA velocity/cells/800.csv")
umap_800 = pd.read_csv("../results/RNA velocity/embeddings/800.csv")
clusters_800 = pd.read_csv("../results/RNA velocity/clusters/800.csv")
sample_800_loom = anndata.read_loom("../results/kb_count/800/counts_unfiltered/adata.loom")

# %%
sample_795 = pd.read_csv("../results/RNA velocity/cells/795.csv")
umap_795 = pd.read_csv("../results/RNA velocity/embeddings/795.csv")
clusters_795 = pd.read_csv("../results/RNA velocity/clusters/795.csv")
sample_795_loom = anndata.read_loom("../results/kb_count/795/counts_unfiltered/adata.loom")

# %%
sample_797 = pd.read_csv("../results/RNA velocity/cells/797.csv")
umap_797 = pd.read_csv("../results/RNA velocity/embeddings/797.csv")
clusters_797 = pd.read_csv("../results/RNA velocity/clusters/797.csv")
sample_797_loom = anndata.read_loom("../results/kb_count/797/counts_unfiltered/adata.loom")

# %%
clusters_792 = pd.read_csv("../results/RNA velocity/clusters/792.csv")
clusters_780 = pd.read_csv("../results/RNA velocity/clusters/780.csv")
clusters_797 = pd.read_csv("../results/RNA velocity/clusters/797.csv")
clusters_795 = pd.read_csv("../results/RNA velocity/clusters/795.csv")
clusters_800 = pd.read_csv("../results/RNA velocity/clusters/800.csv")
clusters_786 = pd.read_csv("../results/RNA velocity/clusters/786.csv")
clusters_789 = pd.read_csv("../results/RNA velocity/clusters/789.csv")
clusters_791 = pd.read_csv("../results/RNA velocity/clusters/791.csv")
clusters_793 = pd.read_csv("../results/RNA velocity/clusters/793.csv")
clusters_778 = pd.read_csv("../results/RNA velocity/clusters/778.csv")
clusters_779 = pd.read_csv("../results/RNA velocity/clusters/779.csv")
clusters_794 = pd.read_csv("../results/RNA velocity/clusters/794.csv")

# %%
sample_792_loom = sample_792_loom[np.isin(sample_792_loom.obs.index,sample_792["barcodes"])]
sample_780_loom = sample_780_loom[np.isin(sample_780_loom.obs.index,sample_780["barcodes"])]
sample_794_loom = sample_794_loom[np.isin(sample_794_loom.obs.index,sample_794["barcodes"])]
sample_779_loom = sample_779_loom[np.isin(sample_779_loom.obs.index,sample_779["barcodes"])]
sample_778_loom = sample_778_loom[np.isin(sample_778_loom.obs.index,sample_778["barcodes"])]
sample_793_loom = sample_793_loom[np.isin(sample_793_loom.obs.index,sample_793["barcodes"])]
sample_791_loom = sample_791_loom[np.isin(sample_791_loom.obs.index,sample_791["barcodes"])]
sample_789_loom = sample_789_loom[np.isin(sample_789_loom.obs.index,sample_789["barcodes"])]
sample_786_loom = sample_786_loom[np.isin(sample_786_loom.obs.index,sample_786["barcodes"])]
sample_800_loom = sample_800_loom[np.isin(sample_800_loom.obs.index,sample_800["barcodes"])]
sample_795_loom = sample_795_loom[np.isin(sample_795_loom.obs.index,sample_795["barcodes"])]
sample_797_loom = sample_797_loom[np.isin(sample_797_loom.obs.index,sample_797["barcodes"])]

# %%
sample_797_loom = sample_797_loom[np.isin(sample_797_loom.obs.index,sample_797["barcodes"])]

# %%
sample_792_loom_index = pd.DataFrame(sample_792_loom.obs.index)
sample_792_loom_index = sample_792_loom_index.rename(columns = {0:'barcodes'})
umap_ordered = sample_792_loom_index.merge(umap_792, on = "barcodes")
umap_ordered = umap_ordered.iloc[:,2:]
sample_792_loom.obsm['X_umap'] = umap_ordered.values
clusters_ordered_792 = sample_792_loom_index.merge(clusters_792, on = "barcodes")
clusters_ordered_792
sample_792_loom.obs['Clusters'] = clusters_ordered_792.iloc[:,2].values
sample_792_loom.uns['Cluster_colors'] = clusters_ordered_792.iloc[:,3].values

# %%
sample_797_loom_index = pd.DataFrame(sample_797_loom.obs.index)
sample_797_loom_index = sample_797_loom_index.rename(columns = {0:'barcodes'})
umap_ordered = sample_797_loom_index.merge(umap_797, on = "barcodes")
umap_ordered
umap_ordered = umap_ordered.iloc[:,2:]
sample_797_loom.obsm['X_umap'] = umap_ordered.values
clusters_ordered_797 = sample_797_loom_index.merge(clusters_797, on = "barcodes")
clusters_ordered_797
sample_797_loom.obs['Clusters'] = clusters_ordered_797.iloc[:,2].values
sample_797_loom.uns['Cluster_colors'] = clusters_ordered_797.iloc[:,3].values

# %%
sample_795_loom_index = pd.DataFrame(sample_795_loom.obs.index)
sample_795_loom_index = sample_795_loom_index.rename(columns = {0:'barcodes'})
umap_ordered = sample_795_loom_index.merge(umap_795, on = "barcodes")
umap_ordered
umap_ordered = umap_ordered.iloc[:,2:]
sample_795_loom.obsm['X_umap'] = umap_ordered.values
clusters_ordered_795 = sample_795_loom_index.merge(clusters_795, on = "barcodes")
clusters_ordered_795
sample_795_loom.obs['Clusters'] = clusters_ordered_795.iloc[:,2].values
sample_795_loom.uns['Cluster_colors'] = clusters_ordered_795.iloc[:,3].values

# %%
sample_800_loom_index = pd.DataFrame(sample_800_loom.obs.index)
sample_800_loom_index = sample_800_loom_index.rename(columns = {0:'barcodes'})
umap_ordered = sample_800_loom_index.merge(umap_800, on = "barcodes")
umap_ordered
umap_ordered = umap_ordered.iloc[:,2:]
sample_800_loom.obsm['X_umap'] = umap_ordered.values
clusters_ordered_800 = sample_800_loom_index.merge(clusters_800, on = "barcodes")
clusters_ordered_800
sample_800_loom.obs['Clusters'] = clusters_ordered_800.iloc[:,2].values
sample_800_loom.uns['Cluster_colors'] = clusters_ordered_800.iloc[:,3].values

# %%
sample_786_loom_index = pd.DataFrame(sample_786_loom.obs.index)
sample_786_loom_index = sample_786_loom_index.rename(columns = {0:'barcodes'})
umap_ordered = sample_786_loom_index.merge(umap_786, on = "barcodes")
umap_ordered
umap_ordered = umap_ordered.iloc[:,2:]
sample_786_loom.obsm['X_umap'] = umap_ordered.values
clusters_ordered_786 = sample_786_loom_index.merge(clusters_786, on = "barcodes")
clusters_ordered_786
sample_786_loom.obs['Clusters'] = clusters_ordered_786.iloc[:,2].values
sample_786_loom.uns['Cluster_colors'] = clusters_ordered_786.iloc[:,3].values

# %%
sample_789_loom_index = pd.DataFrame(sample_789_loom.obs.index)
sample_789_loom_index = sample_789_loom_index.rename(columns = {0:'barcodes'})
umap_ordered = sample_789_loom_index.merge(umap_789, on = "barcodes")
umap_ordered
umap_ordered = umap_ordered.iloc[:,2:]
sample_789_loom.obsm['X_umap'] = umap_ordered.values
clusters_ordered_789 = sample_789_loom_index.merge(clusters_789, on = "barcodes")
clusters_ordered_789
sample_789_loom.obs['Clusters'] = clusters_ordered_789.iloc[:,2].values
sample_789_loom.uns['Cluster_colors'] = clusters_ordered_789.iloc[:,3].values

# %%
sample_791_loom_index = pd.DataFrame(sample_791_loom.obs.index)
sample_791_loom_index = sample_791_loom_index.rename(columns = {0:'barcodes'})
umap_ordered = sample_791_loom_index.merge(umap_791, on = "barcodes")
umap_ordered
umap_ordered = umap_ordered.iloc[:,2:]
sample_791_loom.obsm['X_umap'] = umap_ordered.values
clusters_ordered_791 = sample_791_loom_index.merge(clusters_791, on = "barcodes")
clusters_ordered_791
sample_791_loom.obs['Clusters'] = clusters_ordered_791.iloc[:,2].values
sample_791_loom.uns['Cluster_colors'] = clusters_ordered_791.iloc[:,3].values

# %%
sample_793_loom_index = pd.DataFrame(sample_793_loom.obs.index)
sample_793_loom_index = sample_793_loom_index.rename(columns = {0:'barcodes'})
umap_ordered = sample_793_loom_index.merge(umap_793, on = "barcodes")
umap_ordered
umap_ordered = umap_ordered.iloc[:,2:]
sample_793_loom.obsm['X_umap'] = umap_ordered.values
clusters_ordered_793 = sample_793_loom_index.merge(clusters_793, on = "barcodes")
clusters_ordered_793
sample_793_loom.obs['Clusters'] = clusters_ordered_793.iloc[:,2].values
sample_793_loom.uns['Cluster_colors'] = clusters_ordered_793.iloc[:,3].values

# %%
sample_778_loom_index = pd.DataFrame(sample_778_loom.obs.index)
sample_778_loom_index = sample_778_loom_index.rename(columns = {0:'barcodes'})
umap_ordered = sample_778_loom_index.merge(umap_778, on = "barcodes")
umap_ordered
umap_ordered = umap_ordered.iloc[:,2:]
sample_778_loom.obsm['X_umap'] = umap_ordered.values
clusters_ordered_778 = sample_778_loom_index.merge(clusters_778, on = "barcodes")
clusters_ordered_778
sample_778_loom.obs['Clusters'] = clusters_ordered_778.iloc[:,2].values
sample_778_loom.uns['Cluster_colors'] = clusters_ordered_778.iloc[:,3].values

# %%
sample_779_loom_index = pd.DataFrame(sample_779_loom.obs.index)
sample_779_loom_index = sample_779_loom_index.rename(columns = {0:'barcodes'})
umap_ordered = sample_779_loom_index.merge(umap_779, on = "barcodes")
umap_ordered
umap_ordered = umap_ordered.iloc[:,2:]
sample_779_loom.obsm['X_umap'] = umap_ordered.values
clusters_ordered_779 = sample_779_loom_index.merge(clusters_779, on = "barcodes")
clusters_ordered_779
sample_779_loom.obs['Clusters'] = clusters_ordered_779.iloc[:,2].values
sample_779_loom.uns['Cluster_colors'] = clusters_ordered_779.iloc[:,3].values

# %%
sample_794_loom_index = pd.DataFrame(sample_794_loom.obs.index)
sample_794_loom_index = sample_794_loom_index.rename(columns = {0:'barcodes'})
umap_ordered = sample_794_loom_index.merge(umap_794, on = "barcodes")
umap_ordered
umap_ordered = umap_ordered.iloc[:,2:]
sample_794_loom.obsm['X_umap'] = umap_ordered.values
clusters_ordered_794 = sample_794_loom_index.merge(clusters_794, on = "barcodes")
clusters_ordered_794
sample_794_loom.obs['Clusters'] = clusters_ordered_794.iloc[:,2].values
sample_794_loom.uns['Cluster_colors'] = clusters_ordered_794.iloc[:,3].values

# %%
sample_780_loom_index = pd.DataFrame(sample_780_loom.obs.index)
sample_780_loom_index = sample_780_loom_index.rename(columns = {0:'barcodes'})
umap_ordered = sample_780_loom_index.merge(umap_780, on = "barcodes")
umap_ordered
umap_ordered = umap_ordered.iloc[:,2:]
sample_780_loom.obsm['X_umap'] = umap_ordered.values
clusters_ordered_780 = sample_780_loom_index.merge(clusters_780, on = "barcodes")
clusters_ordered_780
sample_780_loom.obs['Clusters'] = clusters_ordered_780.iloc[:,2].values
sample_780_loom.uns['Cluster_colors'] = clusters_ordered_780.iloc[:,3].values

# %%
con_looms = sample_792_loom.concatenate(sample_780_loom, sample_794_loom, sample_779_loom, sample_778_loom,
                                       sample_793_loom, sample_791_loom, sample_789_loom, sample_786_loom,
                                       sample_800_loom, sample_795_loom, sample_797_loom)

# %%
# con_colors = pd.concat([clusters_ordered_780, clusters_ordered_780, clusters_ordered_794, clusters_ordered_779, 
#                                              clusters_ordered_778, clusters_ordered_793, clusters_ordered_791, 
#                                              clusters_ordered_789, clusters_ordered_786, clusters_ordered_800,
#                                              clusters_ordered_795, clusters_ordered_797])

# %%
# con_looms.uns['Cluster_colors'] = con_colors.iloc[:,3].values

# %%
scv.pp.filter_and_normalize(con_looms)
scv.pp.moments(con_looms)
scv.tl.velocity(con_looms, mode = "stochastic")
scv.tl.velocity_graph(con_looms)
scv.pl.velocity_embedding(con_looms, basis = 'umap')
# color = sample_one.uns['Cluster_colors']
# Out:
# Normalized count data: X, spliced, unspliced.
# Logarithmized X.
# computing neighbors
#     finished (0:00:19) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:18) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# computing velocities
#     finished (0:01:58) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph
#     finished (0:15:01) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:09) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)

# %%
ident_colors = ["#A52A2A","#D2B48C", "#6B8E23", "#32CD32", "#4682B4", "#9370DB",
                                   "#DB7093", "#BC8F8F", "#808080"]
scv.pl.velocity_embedding_stream(con_looms, basis = "umap", color = "Clusters", palette = ident_colors, 
                                 dpi = 300, legend_loc = "right",
                                save = 'velocity_stream_clusters2.png')
# Out:
# saving figure to file ./figures/scvelo_velocity_stream_clusters2.png
